# %% [markdown]
# <a href="https://colab.research.google.com/github/d0ubleyuu/IMDB-Movies-Review/blob/main/IMDB_Film_Review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url = "https://imdb-api.com/API/Search/k_a74bxqbp/suzume"
 
payload = {}
headers= {}
 
response = requests.request("GET", url, headers=headers, data = payload)
 
print(response.text.encode('utf8'))
# Out:
# b'{"searchType":"Title","expression":"suzume","results":[{"id":"tt16428256","resultType":"Title","image":"https://m.media-amazon.com/images/M/MV5BODhhY2M5NjEtZTc0OC00MDE5LWJiMWQtYTZkMTMwMTA0NmZjXkEyXkFqcGdeQXVyMTEwMjgyMzIz._V1_Ratio0.7027_AL_.jpg","title":"Suzume","description":"2022 Nanoka Hara, Hokuto Matsumura"},{"id":"tt0422446","resultType":"Title","image":"https://m.media-amazon.com/images/M/MV5BOTA2YzI4ZTAtN2NiMi00YTg4LThjZmQtZWFmYWVjNmRlOGNiXkEyXkFqcGdeQXVyNzQ1NDIxMDQ@._V1_Ratio0.6757_AL_.jpg","title":"Hyotan suzume","description":"1959 Kiyoshi Kawakubo"},{"id":"tt5175822","resultType":"Title","image":"https://m.media-amazon.com/images/M/MV5BMDcyNTAzMmYtMzViZS00ZDhkLWI5NmUtNTJlM2VmMGMwODQ5XkEyXkFqcGdeQXVyMjQxNzY5NTc@._V1_Ratio0.7027_AL_.jpg","title":"Umi suzume","description":"2016 Rina Takeda, Yutaka Kobayashi"},{"id":"tt4328440","resultType":"Title","image":"","title":"Shitakiri suzume","description":"1917 Short"},{"id":"tt0440843","resultType":"Title","image":"https://m.me
# ...

# %%
url = "https://imdb-api.com/id/API/Reviews/k_a74bxqbp/tt16428256"
 
payload = {}
headers= {}
 
response = requests.request("GET", url, headers=headers, data = payload)
 
print(response.text.encode('utf8'))
# Out:
# b'{"imDbId":"tt16428256","title":"Suzume","fullTitle":"Suzume (2022)","type":"Movie","year":"2022","items":[{"username":"yshr-04651","userUrl":"https://www.imdb.com/user/ur79935693","reviewLink":"https://www.imdb.com/review/rw8668388","warningSpoilers":false,"date":"11 November 2022","rate":"10","helpful":"68 out of 73 found this helpful.","title":"One of the best of all Shinkai\'s films","content":"1 Comparison with past worksSuzume is completely different from Your name and Weathering with you.This film does not have plot twists that Your name has.Additionally, this film may not contain the willpower portrayed in Weathering with you.However, this film may contain something necessary to live in this world.2 ContentsThis film evokes memories of a serious incident in Japan for the present generation, and also allows future generations to inherit those memories.This film may teach us something necessary to overcome that incident.In my opinion, this film may be comparable to Your name."
# ...
